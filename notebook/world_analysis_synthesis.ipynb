# %%
# %pylab inline
rcParams["figure.figsize"] = (16,5)
from scipy.io import wavfile
import pyworld
import pysptk
import IPython
from IPython.display import Audio
import librosa
import librosa.display
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from nnmnkwii.preprocessing import trim_zeros_frames, remove_zeros_frames
import re
from nnmnkwii.io import hts

# %%
from glob import glob

# %%
import os

# %%
import csv

# %%
alpha=pysptk.util.mcepalpha(16000)

# %%
alpha
# Out:
# 0.41000000000000003

# %%
def resynthesis(ori_dir, target_dir):
    """
        analysis and resynthesis speech
    """
    for wav_path in glob(ori_dir+"/*.wav"):
        basename=os.path.basename(wav_path)
        fs, x = wavfile.read(wav_path)
        x = x.astype(np.float64)
        f0, timeaxis = pyworld.harvest(x, fs, frame_period=5, f0_floor=71.0, f0_ceil=700)
        spectrogram = pyworld.cheaptrick(x, f0, timeaxis, fs)
        aperiodicity = pyworld.d4c(x, f0, timeaxis, fs)
        # compression
        bap = pyworld.code_aperiodicity(aperiodicity, fs)
        mgc = pysptk.sp2mc(spectrogram, 59, alpha=alpha)
        # f0 modification
        f0_mod=np.zeros(f0.shape)
        non_zeros_indices = np.where(f0!=0)[0]
        f0_mean=np.mean(f0[non_zeros_indices])
        
        # f0 mean
#         f0_mod[non_zeros_indices] = f0_mean
        # f0 increase 
            
        # f0 add noise
#         f0_noise = np.random.rand(len(f0_mod))-0.5
#         f0_mod[non_zeros_indices] = f0[non_zeros_indices]-100*f0_noise[non_zeros_indices]
        # recovery
        # ap_mod
        fake_ap = np.zeros(aperiodicity.shape)
        spectrogram_recover = pysptk.mc2sp(mgc, fftlen=fftlen, alpha=alpha)
        aperiodicity_recover = pyworld.decode_aperiodicity(bap.astype(np.float64), fs, fftlen)
        generated_waveform = pyworld.synthesize(f0, spectrogram_recover,fake_ap, fs, 5)
        generated_waveform = generated_waveform / np.max(np.abs(generated_waveform)) * 32767
        dst_path=os.path.join(target_dir, basename)
        wavfile.write(dst_path, fs, generated_waveform.astype(np.int16))

# %%
def analysis(lab_dir, ori_dir,target_dir,csv_file):
    """
        analysis and resynthesis speech
    """
#     csv_fid = open(csv_file,'w')
#     csv_writer = csv.writer(csv_fid)
    story_map = {""}
    for wav_path in glob(ori_dir+"/*.wav"):
        basename=os.path.basename(wav_path)
        utt_id = basename.replace('.wav','')
        print(basename)
        x, fs = librosa.core.load(wav_path,sr=16000)
        x = x.astype(np.float64)
        label_path = os.path.join(lab_dir, basename.replace('wav','lab'))
        print(label_path)
        labels = hts.load(label_path)
        silence_indices = labels.silence_frame_indices()
        f0, timeaxis = pyworld.harvest(x, fs, frame_period=5, f0_floor=71.0, f0_ceil=700)
        spectrogram = pyworld.cheaptrick(x, f0, timeaxis, fs)
        aperiodicity = pyworld.d4c(x, f0, timeaxis, fs)
        silence_removed_spectrogram = np.delete(spectrogram[:labels.num_frames()], silence_indices, axis=0)
        silence_removed_f0 = np.delete(f0[:labels.num_frames()], silence_indices)
        silence_removed_aperiodicity = np.delete(aperiodicity[:labels.num_frames()],
                                         silence_indices, axis=0)    
        mc = pysptk.sp2mc(silence_removed_spectrogram, 39, alpha=alpha)
        bap = pyworld.code_aperiodicity(silence_removed_aperiodicity, fs)
        rmse_en = librosa.feature.rmse(x)
        mean_rmse_en = np.mean(rmse_en)
        var_rmse_en = np.var(rmse_en)
        f0 = f0[:, None]
        nonzero_indices = np.nonzero(f0)
        lf0 = np.log(f0[nonzero_indices])
        lf0_mean = np.mean(lf0)
        lf0_var = np.var(lf0)
        mc_mean = np.mean(mc,axis=0)
        mc_var = np.var(mc,axis=0)
        mc_mean_list = list(mc_mean)
        mc_var_list = list(mc_var)
        csv_row = [utt_id,lf0_mean,lf0_var, mean_rmse_en, var_rmse_en] + mc_mean_list + mc_var_list
        csv_writer.writerow(csv_row)
    csv_fid.close()
#         silence_removed_spectrogram = np.delete(spectrogram[:labels.num_frames()], silence_indices, axis=0)
#         silence_removed_f0 = np.delete(f0[:labels.num_frames()], silence_indices)
#         silence_removed_aperiodicity = np.delete(aperiodicity[:labels.num_frames()],
#                                          silence_indices, axis=0)
#         y = pyworld.synthesize(silence_removed_f0, silence_removed_spectrogram, silence_removed_aperiodicity,
#                       fs, 5)
#         dst_path=os.path.join(target_dir, basename)
#         librosa.output.write_wav(dst_path,y,sr=fs)

# %%
def enery_statis(lab_dir, ori_dir,target_dir,csv_file):
    """
        analysis and resynthesis speech
    """
#     csv_fid = open(csv_file,'w')
#     csv_writer = csv.writer(csv_fid)
    story_map = {"s100":0, "s101":1,"s102":2,"s103":3,"s104":4,"s26":5,"s27":6,"s29":7,"s30":8,"s31":9,"s57":10,"s58":11,"s59":12,"s105":13}
    for s_key in story_map.keys():
        story_aver_
        for wav_path in glob(ori_dir+"/*.wav"):
            basename=os.path.basename(wav_path)
            utt_id = basename.replace('.wav','')
            s_index = re.split('_',utt_id)[0]
            if s_key != s_index:
                continue
            x, fs = librosa.core.load(wav_path,sr=16000)
            x = x.astype(np.float64)
            label_path = os.path.join(lab_dir, basename.replace('wav','lab'))
            labels = hts.load(label_path)
            silence_indices = labels.silence_frame_indices()
            rmse_en = librosa.feature.rmse(x)

# %%
story_map = {"s100":0, "s101":1,"s102":2,"s103":3,"s104":4,"s26":5,"s27":6,"s29":7,"s30":8,"s31":9,"s57":10,"s58":11,"s59":12,"s105":13}
for s_key in story_map.keys():
    total_duration = 0
    total_utterance = 0
    for wav_path in glob(ori_dir+"/*.wav"):
        basename=os.path.basename(wav_path)
        utt_id = basename.replace('.wav','')
        s_index = re.split('_',utt_id)[0]
        if s_key != s_index:
            continue
        x, fs = librosa.core.load(wav_path,sr=16000)
        total_duration += size(x)//16000
        total_utterance +=1
    print("story index {0}, total duration {1}, total utterance {2}".format(s_key, total_duration, total_utterance))
# Out:
# story index s100, total duration 324, total utterance 59
# story index s101, total duration 427, total utterance 66
# story index s102, total duration 487, total utterance 68
# story index s103, total duration 328, total utterance 49
# story index s104, total duration 571, total utterance 112
# story index s26, total duration 288, total utterance 42
# story index s27, total duration 438, total utterance 68
# story index s29, total duration 459, total utterance 75
# story index s30, total duration 413, total utterance 53
# story index s31, total duration 229, total utterance 37
# story index s57, total duration 312, total utterance 37
# story index s58, total duration 159, total utterance 20
# story index s59, total duration 212, total utterance 24
# story index s105, total duration 294, total utterance 50

# %%
lab_dir="/home/patrick/corpous/name_clean3/label_phone_align"
ori_dir="/home/patrick/corpous/name_clean3"
target_dir="/home/patrick/corpous/name_clean3/s100/remove_silence"
csv_file="/home/patrick/corpous/name_clean3/stats.csv"
analysis(lab_dir, ori_dir,target_dir,csv_file)
# Out:
# s102_24.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102
12.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s58_out_12.lab
# s27_out_14a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_14a.lab
# s29_out_40.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_40.lab
# s100_1.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_1.lab
# s31_out_1a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_1a.lab
# s102_22.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_22.lab
# s103_32.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_32.lab
# s29_out_30.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_30.lab
# s101_37a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_37a.lab
# s102_57.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_57.lab
# s101_49.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_49.lab
# s30_out_36b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_36b.lab
# s59_out_14.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s59_out_14.lab
# s105_46.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_46.lab
# s102_2.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_2.lab
# s27_out_21a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_21a.lab
# s103_25.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_25.lab
# s103_24.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_24.lab
# s103_46.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_46.lab
# s102_34.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_34.lab
# s27_out_18.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_18.lab
# s103_12.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_12.lab
# s58_out_1.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s58_out_1.lab
# s59_out_12.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s59_out_12.lab
# s102_27.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_27.lab
# s27_out_40b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_40b.lab
# s101_8.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_8.lab
# s104_86.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_86.lab
# s105_33.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_33.lab
# s27_out_8a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_8a.lab
# s103_16.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_16.lab
# s27_out_16a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_16a.lab
# s102_48.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_48.lab
# s101_27a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_27a.lab
# s59_out_13a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s59_out_13a.lab
# s104_95.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_95.lab
# s102_62.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_62.lab
# s100_18.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_18.lab
# s30_out_21.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_21.lab
# s100_29a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_29a.lab
# s59_out_2b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s59_out_2b.lab
# s31_out_11b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_11b.lab
# s27_out_0.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_0.lab
# s58_out_16.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s58_out_16.lab
# s30_out_38.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_38.lab
# s27_out_43.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_43.lab
# s29_out_27.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_27.lab
# s26_out_26.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_26.lab
# s57_out_4.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_4.lab
# s58_out_14b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s58_out_14b.lab
# s101_36b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_36b.lab
# s105_38.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_38.lab
# s29_out_47b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_47b.lab
# s101_1b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_1b.lab
# s104_16.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_16.lab
# s104_35.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_35.lab
# s105_45.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_45.lab
# s29_out_55.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_55.lab
# s26_out_4b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_4b.lab
# s103_37.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_37.lab
# s27_out_25a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_25a.lab
# s26_out_0.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_0.lab
# s57_out_15.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_15.lab
# s104_47.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_47.lab
# s29_out_38a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_38a.lab
# s105_35.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_35.lab
# s26_out_22.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_22.lab
# s103_5.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_5.lab
# s59_out_5.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s59_out_5.lab
# s31_out_9b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_9b.lab
# s59_out_6a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s59_out_6a.lab
# s104_57.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_57.lab
# s104_61.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_61.lab
# s104_13.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_13.lab
# s105_8.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_8.lab
# s27_out_30.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_30.lab
# s100_25b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_25b.lab
# s31_out_0.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_0.lab
# s104_65.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_65.lab
# s29_out_21b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_21b.lab
# s26_out_8.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_8.lab
# s104_18.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_18.lab
# s57_out_30.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_30.lab
# s104_59.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_59.lab
# s104_80.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_80.lab
# s31_out_14a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_14a.lab
# s100_14.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_14.lab
# s27_out_13a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_13a.lab
# s31_out_17.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_17.lab
# s29_out_15a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_15a.lab
# s100_27a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_27a.lab
# s103_26.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_26.lab
# s27_out_32.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_32.lab
# s30_out_13.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_13.lab
# s104_2.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_2.lab
# s100_12a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_12a.lab
# s26_out_14.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_14.lab
# s102_7.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_7.lab
# s104_54.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_54.lab
# s29_out_13.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_13.lab
# s26_out_2b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_2b.lab
# s104_70.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_70.lab
# s105_7.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_7.lab
# s57_out_5.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_5.lab
# s101_6.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_6.lab
# s101_12.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_12.lab
# s57_out_11.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_11.lab
# s104_111.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_111.lab
# s29_out_20.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_20.lab
# s101_31.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_31.lab
# s29_out_18b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_18b.lab
# s57_out_7.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_7.lab
# s29_out_31.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_31.lab
# s29_out_12.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_12.lab
# s104_41.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_41.lab
# s101_38.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_38.lab
# s57_out_18.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_18.lab
# s103_47.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_47.lab
# s103_30.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_30.lab
# s102_44.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_44.lab
# s100_24b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_24b.lab
# s102_53.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_53.lab
# s100_33.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_33.lab
# s101_1a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_1a.lab
# s102_40.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_40.lab
# s26_out_12.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_12.lab
# s30_out_25.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_25.lab
# s104_79.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_79.lab
# s101_15.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_15.lab
# s31_out_2.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_2.lab
# s57_out_6.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_6.lab
# s57_out_28.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_28.lab
# s101_43.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_43.lab
# s101_36a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_36a.lab
# s31_out_7.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_7.lab
# s27_out_38.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_38.lab
# s27_out_1.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_1.lab
# s100_9.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_9.lab
# s57_out_21.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_21.lab
# s104_0.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_0.lab
# s27_out_2.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_2.lab
# s58_out_8.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s58_out_8.lab
# s101_44.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_44.lab
# s100_30.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_30.lab
# s104_103.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_103.lab
# s104_8.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_8.lab
# s30_out_24.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_24.lab
# s100_13b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_13b.lab
# s100_5b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_5b.lab
# s29_out_50.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_50.lab
# s29_out_33a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_33a.lab
# s29_out_18a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_18a.lab
# s103_27.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_27.lab
# s103_17.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_17.lab
# s29_out_41.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_41.lab
# s29_out_2b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_2b.lab
# s27_out_19.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_19.lab
# s31_out_21b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_21b.lab
# s105_41.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_41.lab
# s31_out_15.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_15.lab
# s30_out_40b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_40b.lab
# s102_19.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_19.lab
# s104_102.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_102.lab
# s57_out_17a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_17a.lab
# s57_out_10.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_10.lab
# s30_out_12a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_12a.lab
# s29_out_34b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_34b.lab
# s27_out_3.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_3.lab
# s104_30.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_30.lab
# s101_11.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_11.lab
# s59_out_10a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s59_out_10a.lab
# s104_34.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_34.lab
# s27_out_24.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_24.lab
# s29_out_2a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_2a.lab
# s57_out_1a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_1a.lab
# s30_out_23.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_23.lab
# s102_33.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_33.lab
# s57_out_22.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_22.lab
# s103_43.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_43.lab
# s27_out_41a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_41a.lab
# s102_31.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_31.lab
# s31_out_13b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_13b.lab
# s102_52.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_52.lab
# s31_out_9a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_9a.lab
# s30_out_29a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_29a.lab
# s104_110.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_110.lab
# s104_55.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_55.lab
# s26_out_18.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_18.lab
# s27_out_33a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_33a.lab
# s27_out_22.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_22.lab
# s27_out_27.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_27.lab
# s59_out_10b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s59_out_10b.lab
# s101_30.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_30.lab
# s26_out_25a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_25a.lab
# s29_out_38b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_38b.lab
# s30_out_9.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_9.lab
# s58_out_10b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s58_out_10b.lab
# s29_out_34a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_34a.lab
# s57_out_2.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_2.lab
# s100_39.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_39.lab
# s30_out_14.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_14.lab
# s104_64.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_64.lab
# s27_out_36.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_36.lab
# s100_17b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_17b.lab
# s29_out_51a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_51a.lab
# s100_13a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_13a.lab
# s101_17.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_17.lab
# s105_27.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_27.lab
# s103_39.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_39.lab
# s105_19.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_19.lab
# s29_out_3.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_3.lab
# s104_31.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_31.lab
# s102_36.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_36.lab
# s105_36.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_36.lab
# s103_28.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_28.lab
# s29_out_16.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_16.lab
# s105_47.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_47.lab
# s101_42.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_42.lab
# s31_out_20b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s31_out_20b.lab
# s26_out_19.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_19.lab
# s104_26.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_26.lab
# s59_out_16.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s59_out_16.lab
# s59_out_2a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s59_out_2a.lab
# s105_43.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_43.lab
# s27_out_37.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_37.lab
# s29_out_10.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_10.lab
# s57_out_26.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_26.lab
# s101_27b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_27b.lab
# s26_out_11.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_11.lab
# s29_out_8.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_8.lab
# s104_12.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_12.lab
# s104_76.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_76.lab
# s26_out_16.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_16.lab
# s29_out_4a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_4a.lab
# s29_out_53.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_53.lab
# s30_out_3.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_3.lab
# s102_61.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_61.lab
# s105_3.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_3.lab
# s30_out_32.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_32.lab
# s27_out_35b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_35b.lab
# s27_out_17b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_17b.lab
# s105_42.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_42.lab
# s26_out_7.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_7.lab
# s30_out_20.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_20.lab
# s27_out_17a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_17a.lab
# s100_2b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_2b.lab
# s29_out_39b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_39b.lab
# s103_20.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_20.lab
# s100_15.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_15.lab
# s100_22c.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_22c.lab
# s26_out_13.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s26_out_13.lab
# s104_36.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_36.lab
# s27_out_40a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_40a.lab
# s103_44.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_44.lab
# s29_out_36.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_36.lab
# s101_22a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_22a.lab
# s30_out_34b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_34b.lab
# s102_58.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_58.lab
# s29_out_1.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_1.lab
# s101_47b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_47b.lab
# s103_18.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_18.lab
# s103_19.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_19.lab
# s27_out_28a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_28a.lab
# s29_out_0.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_0.lab
# s27_out_31.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_31.lab
# s102_47.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_47.lab
# s30_out_39.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_39.lab
# s27_out_8b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s27_out_8b.lab
# s102_54.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_54.lab
# s57_out_19.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_19.lab
# s100_12b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s100_12b.lab
# s30_out_1a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_1a.lab
# s29_out_35.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_35.lab
# s57_out_16.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_16.lab
# s105_14.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s105_14.lab
# s103_22.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s103_22.lab
# s104_100.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_100.lab
# s57_out_24a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s57_out_24a.lab
# s29_out_23a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_23a.lab
# s30_out_1b.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s30_out_1b.lab
# s101_21.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s101_21.lab
# s104_3.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s104_3.lab
# s29_out_49a.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s29_out_49a.lab
# s102_29.wav
# /home/patrick/corpous/name_clean3/label_phone_align/s102_29.lab

# %%
story_map = {"s100":0, "s101":1,"s102":2,"s103":3,"s104":4,"s26":5,"s27":6,"s29":7,"s30":8,"s31":9,"s57":10,"s58":11,"s59":12,"s105":13}

# %%
y = []
X = []
with open(csv_file,'r') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in spamreader:
        s_index = re.split('_',row[0])[0]
        s_num = story_map[s_index]
        row_data = []
        for sdata in row[1:]:
            row_data.append(float(sdata))
        y.append(s_num)
        X.append(row_data)

# %%
from sklearn.feature_selection import SelectKBest

# %%
from sklearn.feature_selection import chi2

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel

# %%
clf = ExtraTreesClassifier(n_estimators=50)
model = SelectFromModel(clf, prefit=True)

# %%
clf = clf.fit(X[:,0:4], y)

# %%
clf.feature_importances_
# Out:
# array([ 0.19786889,  0.23969402,  0.28439214,  0.27804495])

# %%
y=np.array(y)

# %%
X.shape
# Out:
# (760, 84)

# %%
model1 = SelectKBest(chi2, k=2)

# %%
model1.fit_transform(X[:,0:4],y)
# Out:
# array([[ 0.08488326,  0.04916909],
#        [ 0.07060433,  0.0653136 ],
#        [ 0.0322313 ,  0.02685207],
#        ...,
#        [ 0.09566944,  0.03691672],
#        [ 0.06558673,  0.08833791],
#        [ 0.09796428,  0.04605107]])

# %%
model1.pvalues_
# Out:
# array([ 1.        ,  0.94139061,  0.98556614,  0.99999075])

# %%
wav_path = "/home/patrick/corpous/name_clean3/s100_0.wav"
label_path = "/home/patrick/corpous/name_clean3/label_phone_align/s100_0.lab"
labels = hts.load(label_path)
silence_indices = labels.silence_frame_indices()
x2, fs = librosa.core.load(wav_path,sr=16000)
x2 = x2.astype(np.float64)

# %%
f0, timeaxis = pyworld.harvest(x2, fs, frame_period=5, f0_floor=71.0, f0_ceil=700)
spectrogram = pyworld.cheaptrick(x2, f0, timeaxis, fs)
aperiodicity = pyworld.d4c(x2, f0, timeaxis, fs)

# %%
x3 = 3*x2+0.1

# %%
f0_x3, timeaxis = pyworld.harvest(x3, fs, frame_period=5, f0_floor=71.0, f0_ceil=700)
spectrogram_x3 = pyworld.cheaptrick(x3, f0, timeaxis, fs)
aperiodicity_x3 = pyworld.d4c(x3, f0, timeaxis, fs)

# %%
mc = pysptk.sp2mc(spectrogram, 60, alpha=alpha)
bap = pyworld.code_aperiodicity(aperiodicity, fs)
spectrogram_recover = pysptk.mc2sp(mc, fftlen=1024, alpha=alpha)
aperiodicity_recover = pyworld.decode_aperiodicity(bap.astype(np.float64), fs, 1024)

# %%
plot(mc[112,:])

# %%
silence_removed_spectrogram = np.delete(spectrogram[:labels.num_frames()], silence_indices, axis=0)
silence_removed_f0 = np.delete(f0[:labels.num_frames()], silence_indices)
silence_removed_aperiodicity = np.delete(aperiodicity[:labels.num_frames()],
                                         silence_indices, axis=0)

# %%
mc_mean=np.mean(mc,axis=0)

# %%
mc_mean.shape
# Out:
# (30,)

# %%
mc_var=np.var(mc,axis=0)

# %%
mc_cov = np.cov(np.transpose(mc))

# %%
plot(mc[100:150,7])

# %%
mc.shape
# Out:
# (1318, 30)

# %%
mc_mean = np.mean(mc,axis=0)

# %%
mc_mean.shape
# Out:
# (30,)

# %%
y = pyworld.synthesize(silence_removed_f0, spectrogram_recover, aperiodicity_recover,
                      fs, 5)
librosa.display.waveplot(np.float32(y), sr=fs)
Audio(y, rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
rmse_x_lib=librosa.feature.rmse(x,n_fft=343,hop_length=80)

# %%
plot(rmse_x_lib[0,:])

# %%
rmse_x_lib=librosa.feature.rmse(generated_waveform,n_fft=343,hop_length=80)

# %%
spectrogram.shape
# Out:
# (201, 513)

# %%
librosa_sp = librosa.core.stft(x_lib, n_fft=1024, hop_length=80, win_length=343)

# %%
librosa_sp = np.transpose(librosa_sp)

# %%
mag_librosa_sp = np.abs(librosa_sp)

# %%
plot(mag_librosa_sp[101,:],linewidth=2)
plot(spectrogram[101,:],linewidth=2)

# %%
plot(spectrogram[100,:],linewidth=2)

# %%
plot(20*np.log(spectrogram[114,:]),linewidth=2)

# %%
generated_waveform = pyworld.synthesize(f0, spectrogram,aperiodicity, fs, 5)

# %%
generated_waveform
# Out:
# array([-0.01045088, -0.01048836, -0.01052587, ..., -0.01755288,
#        -0.01874817, -0.01969721])

# %%
spectrogram_recover = pysptk.mc2sp(mgc, fftlen=fftlen, alpha=alpha)
bap = pyworld.code_aperiodicity(aperiodicity, fs)

# %%
aperiodicity_recover = pyworld.decode_aperiodicity(bap.astype(np.float64), fs, fftlen)

# %%
generated_waveform = pyworld.synthesize(f0, spectrogram,aperiodicity, fs, 5)

# %%
non_zeros_indices = np.where(f0!=0)[0]

# %%
f0_mod[non_zeros_indices] = f0[non_zeros_indices]-100*f0_noise[non_zeros_indices]

# %%
plot(f0_modd)

# %%
f0_mean=np.mean(f0[non_zeros_indices])

# %%
f0_mod[non_zeros_indices] = f0_mean

# %%
generated_waveform_mod = pyworld.synthesize(f0_mod, spectrogram,aperiodicity, fs, 5)

# %%
Audio(generated_waveform_mod, rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(generated_waveform, rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
